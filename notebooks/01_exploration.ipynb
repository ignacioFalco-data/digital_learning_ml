# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# > Contexto general
#
# Las plataformas de formación digital enfrentan dos desafíos principales:
#
# *   Altas tasas de abandono.
# *   Variabilidad en el rendimiento académico de los estudiantes.
#
#
# Comprender qué factores influyen en la finalización de un curso y en la puntuación final permite:
#
#
# * Mejorar estrategias pedagógicas.
#
# * Detectar perfiles de riesgo.
#
# * Optimizar recursos académicos.
#
# * Diseñar intervenciones personalizadas.
#
#
#
#
# > Objetivos del Proyecto
#
# Este proyecto aborda dos problemas supervisados distintos:
#
# * **Problema 1: Clasificación**
#
# 1.   Objetivo: Predecir si un estudiante completará o no el curso.
# 2.   Tipo de problema: Clasificación binaria.
# 3.   Variable objetivo: completed.
# 4.   Clases:
#
#       0 → No completa
#
#       1 → Completa
#
#
#
#
#
#
#
# Clases:
#
#
# Distribución actual:
#
# 69% No completa
#
# 31% Completa
#
# Esto implica un desbalance moderado, por lo que:
#
# Accuracy no será suficiente como métrica principal.
#
# Se priorizarán métricas robustas como:
#
# F1-score
#
# Recall
#
# ROC-AUC
#
# 🔹 Problema 2: Regresión
#
# Objetivo:
# Predecir la puntuación final del master.
#
# Tipo de problema: Regresión
#
# Variable objetivo: master_score
#
# Métricas principales:
#
# MAE
#
# RMSE
#
# R²
#
# Este modelo permitirá estimar el desempeño académico esperado a partir de variables disponibles del estudiante.
#
# 📊 Alcance del Modelo
#
# Es importante aclarar que:
#
# El modelo utilizará información completa del curso.
#
# No se dispone de una dimensión temporal que permita predicción temprana real.
#
# Por lo tanto, el enfoque es analítico/predictivo ex-post y no necesariamente operativo en tiempo real.
#
# Esto no invalida el proyecto, pero define su alcance correctamente.
#
# 🧠 Hipótesis Iniciales
#
# Algunas hipótesis a validar durante el EDA:
#
# Variables de engagement (participación, tiempo, interacción) influyen en la finalización.
#
# El desempeño previo impacta en la puntuación final.
#
# Existen patrones diferenciales entre quienes completan y quienes no.
#
# Puede haber variables con riesgo de data leakage.
#
# 📌 Impacto Potencial
#
# Si los modelos alcanzan buen desempeño:
#
# Se podrán identificar patrones de abandono.
#
# Se podrán segmentar estudiantes según riesgo o rendimiento esperado.
#
# Se podrá mejorar la toma de decisiones académicas.

# %% [markdown]
# # **Data Overview**

# %%
import pandas as pd

# %%
df = pd.read_csv('digital_learning_ml.csv', delimiter=',')
